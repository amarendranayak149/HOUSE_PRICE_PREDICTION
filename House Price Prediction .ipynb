# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\maren\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\maren\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
df = pd.read_csv(r"D:\DATA SCIENCE\INNOMATICS\ML\Datasets\housing_price_dataset.csv")

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %% [markdown]
# **Problem Type -- Regression Problem**

# %% [markdown]
# ## 1. Business And Data Understanding

# %%
df.shape
# Out:
# (50000, 6)

# %%
df.memory_usage().sum()
# Out:
# np.int64(2400132)

# %% [markdown]
# * SquareFeet -  Area occupied By the house   --> Numerical    500 -5000
# * Bed Rooms - no of bedrooms in the house   --> Numerical   - 1 - 5
# * Bathrooms - no pof bathrooms in the house   --> Numerical - 1-5
# * Neighborhood - where the house was built   --> Categorical -
# * YearBuilt  - In Which Year it is built   --> Numerical  - 1990 - 2025
# * Price - The Price of House (Output column)   --> Numerical -

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# ## EDA

# %%
df.isna().sum()  #Missing Values
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df.duplicated().sum()  #Duplicates
# Out:
# np.int64(0)

# %%
df['SquareFeet'].min(),df['SquareFeet'].max()
# Out:
# (np.int64(1000), np.int64(2999))

# %%
df['Bedrooms'].min(),df['Bedrooms'].max()
# Out:
# (np.int64(2), np.int64(5))

# %%
df['Bathrooms'].min(),df['Bathrooms'].max()
# Out:
# (np.int64(1), np.int64(3))

# %%
df['YearBuilt'].min(),df['YearBuilt'].max()
# Out:
# (np.int64(1950), np.int64(2021))

# %%
df['Price'].min(),df['Price'].max()
# Out:
# (np.float64(-36588.16539749279), np.float64(492195.2599720151))

# %% [markdown]
# ### Data Cleaning

# %%
import numpy as np

# %%
df['Price'] = np.abs(df['Price'])

# %%
df['Price'].min(),df['Price'].max()
# Out:
# (np.float64(154.77912007166017), np.float64(492195.2599720151))

# %% [markdown]
# * No Missing Values
# * No Duplcicates
# * Outliers are treated

# %%
df['Neighborhood'].unique()
# Out:
# array(['Rural', 'Suburb', 'Urban'], dtype=object)

# %%
df['Neighborhood'] = df['Neighborhood'].map({'Rural':0,'Suburb':1,'Urban':2})

# %%
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt          Price
# 0            2126         4          1             0       1969  215355.283618
# 1            2459         3          2             0       1980  195014.221626
# 2            1860         2          1             1       1970  306891.012076
# 3            2294         2          1             2       1996  206786.787153
# 4            2130         5          2             1       2001  272436.239065
# ...           ...       ...        ...           ...        ...            ...
# 49995        1282         5          3             0       1975  100080.865895
# 49996        2854         2          2             1       1988  374507.656727
# 49997        2979         5          3             1       1962  384110.555590
# 49998        2596         5          2             0       1984  380512.685957
# 49999        1572         5          3             0       2011  221618.583218
#
# ...

# %% [markdown]
# ##### Feature Engineering

# %% [markdown]
# #### 3. Model Building

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt          Price
# 0        2126         4          1             0       1969  215355.283618
# 1        2459         3          2             0       1980  195014.221626
# 2        1860         2          1             1       1970  306891.012076
# 3        2294         2          1             2       1996  206786.787153
# 4        2130         5          2             1       2001  272436.239065

# %%
df[['SquareFeet'	,'Bedrooms',	'Bathrooms',	'Neighborhood',	'YearBuilt']]
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
# 0            2126         4          1             0       1969
# 1            2459         3          2             0       1980
# 2            1860         2          1             1       1970
# 3            2294         2          1             2       1996
# 4            2130         5          2             1       2001
# ...           ...       ...        ...           ...        ...
# 49995        1282         5          3             0       1975
# 49996        2854         2          2             1       1988
# 49997        2979         5          3             1       1962
# 49998        2596         5          2             0       1984
# 49999        1572         5          3             0       2011
#
# [50000 rows x 5 columns]

# %%
df.drop('Price',axis = 1)
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
# 0            2126         4          1             0       1969
# 1            2459         3          2             0       1980
# 2            1860         2          1             1       1970
# 3            2294         2          1             2       1996
# 4            2130         5          2             1       2001
# ...           ...       ...        ...           ...        ...
# 49995        1282         5          3             0       1975
# 49996        2854         2          2             1       1988
# 49997        2979         5          3             1       1962
# 49998        2596         5          2             0       1984
# 49999        1572         5          3             0       2011
#
# [50000 rows x 5 columns]

# %%
X = df.drop('Price',axis = 1)  #Input data
y = df['Price']   #Target Column

# %%
X
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
# 0            2126         4          1             0       1969
# 1            2459         3          2             0       1980
# 2            1860         2          1             1       1970
# 3            2294         2          1             2       1996
# 4            2130         5          2             1       2001
# ...           ...       ...        ...           ...        ...
# 49995        1282         5          3             0       1975
# 49996        2854         2          2             1       1988
# 49997        2979         5          3             1       1962
# 49998        2596         5          2             0       1984
# 49999        1572         5          3             0       2011
#
# [50000 rows x 5 columns]

# %%
y
# Out:
# 0        215355.283618
# 1        195014.221626
# 2        306891.012076
# 3        206786.787153
# 4        272436.239065
#              ...
# 49995    100080.865895
# 49996    374507.656727
# 49997    384110.555590
# 49998    380512.685957
# 49999    221618.583218
# Name: Price, Length: 50000, dtype: float64

# %%
X.shape
# Out:
# (50000, 5)

# %%
y.shape
# Out:
# (50000,)

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(X,y,test_size=0.2,random_state=23)
# Out:
# [       SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
#  20198        2169         2          3             0       1988
#  34103        2568         3          2             1       1977
#  40179        1339         3          3             0       1958
#  34586        2716         2          1             0       1978
#  30725        2307         3          1             0       1974
#  ...           ...       ...        ...           ...        ...
#  9704         2788         4          3             1       1986
#  11190        2557         5          1             1       2004
#  26569        2344         3          2             0       1961
#  9256         1105         5          2             1       2008
#  41555        2248         2          3             2       2020
#
#  [40000 rows x 5 columns],
#         SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
#  49466        1055         3          2             0       1969
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=23)

# %%
X_train.shape
# Out:
# (40000, 5)

# %%
X_test.shape
# Out:
# (10000, 5)

# %% [markdown]
# ### KNN Alogorithm

# %% [markdown]
# * Any uppercase -  Class - dont give the data directly
# * if all are lower case - function - directly the data can be given

# %%
#loading the algorithm
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor()

knn.fit(X_train,y_train)   #training the data on KNN algorithrmn
# Out:
# KNeighborsRegressor()

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr  = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### 4. Model Evaluation

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = knn.predict(X_test)
mean_squared_error(y_pred,y_test)
# Out:
# 2939617716.996368

# %%
y_pred = lr.predict(X_test)
mean_squared_error(y_pred,y_test)
# Out:
# 2437868887.959436

# %%
y_pred = dt.predict(X_test)
mean_squared_error(y_pred,y_test)
# Out:
# 5220876990.726532

# %% [markdown]
# ### 5. Model Deployment

# %%
from sklearn.linear_model import LinearRegression
lr  = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
import pickle

# %%
with open('elite27.pkl','wb') as file:
    pickle.dump(lr,file)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\maren\\INNOMATICS_327\\ML_classes_327\\NOTES\\WEEK 1'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sqft = int(input("Enter the area (sqft):  "))
bed =  int(input("Enter the no of bed rooms ::"))
bath = int(input("Enter the no of bath rooms ::"))
neigh = int(input("Enter the area 0: Rural,1:Suburb,2:urban: "))
year = int(input("Enter the year :: "))

lr.predict([[sqft,bed,bath,neigh,year]])
# Out:
# Enter the area (sqft):   2100
# Enter the no of bed rooms :: 5
# Enter the no of bath rooms :: 2
# Enter the area 0: Rural,1:Suburb,2:urban:  1
# Enter the year ::  2020
# array([241392.45446918])

# %% [markdown]
# y  = mx+c

# %%
lr.coef_
# Out:
# array([  99.32053483, 5078.38800022, 2825.31590133,  776.92432034,
#         -11.06475013])

# %%
lr.intercept_
# Out:
# np.float64(23350.630458787928)

# %%
sqft = int(input("Enter the area (sqft):  "))
bed =  int(input("Enter the no of bed rooms ::"))
bath = int(input("Enter the no of bath rooms ::"))
neigh = int(input("Enter the area 0: Rural,1:Suburb,2:urban: "))
year = int(input("Enter the year :: "))

price = 99.32053483 * sqft + 5078.38800022 * bed + 2825.31590133 * bath + 776.92432034 * neigh  -11.06475013*year +23350.630458787928
# Out:
# Enter the area (sqft):   2100
# Enter the no of bed rooms :: 5
# Enter the no of bath rooms :: 2
# Enter the area 0: Rural,1:Suburb,2:urban:  1
# Enter the year ::  2020

# %%
price
# Out:
# 241392.45446328796
